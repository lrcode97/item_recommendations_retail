# %% [markdown]
# Imports

# %%
from IPython.display import display, HTML
import pandas as pd
import numpy as np
from pathlib import Path
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]

# %%
def get_embeddings(sentences):
  encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

  with torch.no_grad():
      model_output = model(**encoded_input)

  sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

  sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

  return sentence_embeddings

# %%
def table(df):
    df_copy = df.head(300).copy()
    display(HTML("""
        <style>
            .dataframe-container {
                height: 400px;
                overflow: auto;
                width: 100%;
            }
            .dataframe {
                table-layout: fixed;
                width: 100%;
            }
            .dataframe td, .dataframe th {
                white-space: normal;
                word-wrap: break-word;
                word-break: break-word;
                max-width: 150px; /* Adjust this value as needed */
                overflow: hidden;
                text-overflow: ellipsis;
            }
        </style>
        <div class='dataframe-container'>
            """ + df_copy.style.set_table_attributes("class='dataframe'").to_html() + """
        </div>
    """))

# %%
data_dir = Path.cwd() / "data"
data_dir
# Out:
# PosixPath('/Users/lawrence/Documents/PYTHON/item_recommendations_retail/data')

# %%
files = list(data_dir.iterdir())
files
# Out:
# [PosixPath('/Users/lawrence/Documents/PYTHON/item_recommendations_retail/data/recommendations_main.csv'),
#  PosixPath('/Users/lawrence/Documents/PYTHON/item_recommendations_retail/data/custs.csv'),
#  PosixPath('/Users/lawrence/Documents/PYTHON/item_recommendations_retail/data/lift.csv'),
#  PosixPath('/Users/lawrence/Documents/PYTHON/item_recommendations_retail/data/items.csv')]

# %%
custs = pd.read_csv(data_dir / "custs.csv")
items = pd.read_csv(data_dir / "items.csv")
lift = pd.read_csv(data_dir / "lift.csv")

# %% [markdown]
# ## Items that will need placing into other categories

# %%
super_cats_with_less_than_four_items = items.groupby("SUPER_CAT").filter(lambda x: len(x) < 4).SUPER_CAT.unique()
super_cats_with_less_than_four_items
# Out:
# array(['042a172740f7b6de757d54c5c8ae417f4af70326caf49174e3daec81d6f29a8e',
#        '7a5a5e180aa843f2bf55ba649d20145b799e432059079308da4c2fe4dadd8d58',
#        '6ba7d494efdf1a5ab73cad55c6cf76b4c199372ebaf0828c9c1b77ec9e64cfa7',
#        '16e07576851f55b4c8bf497b8ceaac92b9dbcd2f57dbbc2202f7315e334eecb1',
#        'ea1b80d4a3ab48e7a83f0777c7bb851760fdfd644fa67f3234330eca37a22674',
#        '06d2c2d77a6923df8f14ae34f3f6662bc20d1833ec3a623a7b7672e6b5f5d7be',
#        '74c1a1e360223d09e349364e20f179e68c673045857fb3e6f642ac84e81d40fa',
#        '128e9e0029ed6bd2c7b33fab214183b44a6719fa90b40fae65a7a6e4b57413ea',
#        '3f7b2207bad71d03813ba16857e15f95259c820696203c97e51192ff6fd9c03d'],
#       dtype=object)

# %%
items_in_super_cats_with_less_than_four_items = items[items["SUPER_CAT"].isin(super_cats_with_less_than_four_items)][['ITEM', 'ITEM_NAME']]
table(items_in_super_cats_with_less_than_four_items)
# Out:
#         <style>
#             .dataframe-container {
#                 height: 400px;
#                 overflow: auto;
#                 width: 100%;
#             }
#             .dataframe {
#                 table-layout: fixed;
#                 width: 100%;
#             }
#             .dataframe td, .dataframe th {
#                 white-space: normal;
#                 word-wrap: break-word;
#                 word-break: break-word;
#                 max-width: 150px; /* Adjust this value as needed */
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#             }
#         </style>
#         <div class='dataframe-container'>
#             <style type="text/css">
# </style>
# <table id="T_22e77" class='dataframe'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22e77_level0_col0" class="col_heading level0 col0" >ITEM</th>
#       <th id="T_22e77_level0_col1" class="col_heading level0 col1" >ITEM_NAME</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22e77_level0_row0" class="row_heading level0 row0" >18</th>
#       <td id="T_22e77_row0_col0" class="data row0 col0" >d49da2240fcc6c8ce39e6121b992182b3d1b71e9356f4af92ffa13d601a3f369</td>
#       <td id="T_22e77_row0_col1" class="data row0 col1" >Dairy Pride UHT Skimmed Milk 1l</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_22e77_row1_col0" class="data row1 col0" >865b7c05a2859d4bdc0e68e13a7ae03c41ec32940903ef2b82496ea4d1c9e76a</td>
#       <td id="T_22e77_row1_col1" class="data row1 col1" >Dairy Pride Semi Skimmed UHT Milk 1ltr</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row2" class="row_heading level0 row2" >20</th>
#       <td id="T_22e77_row2_col0" class="data row2 col0" >5a7672762401c638088791e8d25fdb13c8dd46b84a270272f6317972fc292f8b</td>
#       <td id="T_22e77_row2_col1" class="data row2 col1" >Rizla Regular Green x 5 Multi Pack</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row3" class="row_heading level0 row3" >21</th>
#       <td id="T_22e77_row3_col0" class="data row3 col0" >0d4376d8f3f3fbdd1b1d705f59a16dda694661c38bfe505951cfb746d4cf15d3</td>
#       <td id="T_22e77_row3_col1" class="data row3 col1" >Swan Extra Slim Filter Tips X120</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row4" class="row_heading level0 row4" >137</th>
#       <td id="T_22e77_row4_col0" class="data row4 col0" >3b47ead8994dd9980ab2bd6fdfc9d667417e07de869e408815c9ee0998241810</td>
#       <td id="T_22e77_row4_col1" class="data row4 col1" >LITTLE ONES DRY FIT  6+EP 30</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row5" class="row_heading level0 row5" >147</th>
#       <td id="T_22e77_row5_col0" class="data row5 col0" >5681e194e8db0231215b34aec6396b185890eba668de6ec5d2d978d490431252</td>
#       <td id="T_22e77_row5_col1" class="data row5 col1" >TV TIMES 22/23</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row6" class="row_heading level0 row6" >148</th>
#       <td id="T_22e77_row6_col0" class="data row6 col0" >dd5f2227014e3cac07caa5fdc6e8651cb88104530d401c3cda67a303f5d92604</td>
#       <td id="T_22e77_row6_col1" class="data row6 col1" >Stamford Street Strawberry &Vanilla Roll</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row7" class="row_heading level0 row7" >149</th>
#       <td id="T_22e77_row7_col0" class="data row7 col0" >56a6972024ec538baf8b0695aa9cc6fcf347f5dbe3c5238f7f6171b75fac81b3</td>
#       <td id="T_22e77_row7_col1" class="data row7 col1" >Stamford Street Fairy Cakes X12</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row8" class="row_heading level0 row8" >150</th>
#       <td id="T_22e77_row8_col0" class="data row8 col0" >c62772b3bf43bafc30d89276129d4fc6e14ac824083eb9ff18df170eb6d1c5a9</td>
#       <td id="T_22e77_row8_col1" class="data row8 col1" >Stamford Street Mini Rolls 102g</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row9" class="row_heading level0 row9" >158</th>
#       <td id="T_22e77_row9_col0" class="data row9 col0" >fcb4860524f4b3f5503a6f6096ade548f01e2374b5f082189b19ceb5eba54487</td>
#       <td id="T_22e77_row9_col1" class="data row9 col1" >TAKE A BREAK</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row10" class="row_heading level0 row10" >164</th>
#       <td id="T_22e77_row10_col0" class="data row10 col0" >db7271041c5d6b2219e9744cf86f02766c1a83ad3ab05f6ef1445c750ac2970d</td>
#       <td id="T_22e77_row10_col1" class="data row10 col1" >JS Lamb Breast CW</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row11" class="row_heading level0 row11" >180</th>
#       <td id="T_22e77_row11_col0" class="data row11 col0" >426d37fa6af40a2e2bbdc88430ef63f7e522ae75482c0454c95879c1fe8c35c0</td>
#       <td id="T_22e77_row11_col1" class="data row11 col1" >Dettol antiseptic disinfectant 750ml</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row12" class="row_heading level0 row12" >196</th>
#       <td id="T_22e77_row12_col0" class="data row12 col0" >2014ccff593820adfe9819723ef9017396107a4fe891b6b26f5d869740ec461a</td>
#       <td id="T_22e77_row12_col1" class="data row12 col1" >JS BRITISH LARGE PORK SHOULDER JOINT CW</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row13" class="row_heading level0 row13" >261</th>
#       <td id="T_22e77_row13_col0" class="data row13 col0" >18d4aee90a94d871723c2f1e59d3fd588df9d09dffa605325f2c68c9b4d8e128</td>
#       <td id="T_22e77_row13_col1" class="data row13 col1" >JS ADW Ultimate Lem 262g 20 washes</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row14" class="row_heading level0 row14" >268</th>
#       <td id="T_22e77_row14_col0" class="data row14 col0" >a323098c08742400d8f75910c203ada6575c62083853c44fe2e112b5986d3ab0</td>
#       <td id="T_22e77_row14_col1" class="data row14 col1" >Stamford St White Fish Fillets 520g</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row15" class="row_heading level0 row15" >291</th>
#       <td id="T_22e77_row15_col0" class="data row15 col0" >5a57844007906428852cb07a1be083e8c301afadafe2eb062f49d807a9a8cd05</td>
#       <td id="T_22e77_row15_col1" class="data row15 col1" >Comfort creations strawberry lily 30w</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row16" class="row_heading level0 row16" >296</th>
#       <td id="T_22e77_row16_col0" class="data row16 col0" >d0eb42d1dcb72179895e3e730bddaa69ce7edd664ecee97dd92e0ed55ef955b2</td>
#       <td id="T_22e77_row16_col1" class="data row16 col1" >Stamford St Mixed Portions Pack 2kg</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row17" class="row_heading level0 row17" >297</th>
#       <td id="T_22e77_row17_col0" class="data row17 col0" >394add7c80c8885edd2682212c672532c2ff470107bcb6ca5933293a21e6a3e1</td>
#       <td id="T_22e77_row17_col1" class="data row17 col1" >Js Frozen Chicken Liver Pots 250g</td>
#     </tr>
#     <tr>
#       <th id="T_22e77_level0_row18" class="row_heading level0 row18" >348</th>
#       <td id="T_22e77_row18_col0" class="data row18 col0" >4c3dc7d1939a786f099795c6c08245514badf09f39184517f921999ff62df18a</td>
#       <td id="T_22e77_row18_col1" class="data row18 col1" >Regina Blitz x4</td>
#     </tr>
#   </tbody>
# </table>
#
#         </div>

# %%
items_with_super_cat_more_than_four_items = items[~items["SUPER_CAT"].isin(super_cats_with_less_than_four_items)]
items_with_super_cat_more_than_four_items
# Out:
#                                                   ITEM  QUANTITY  \
# 0    6446506d5cf328e5e4e0b47f3a2914a86d55b95e8b24f6...    4527.0
# 1    abc0c83eaef2366dbec3b35a478c81547fc451f3666347...    2557.0
# 2    63f3da95314c90b3195468322b10677a17a43d92b4dddc...    2343.0
# 3    232247fa7953669d85b54088b2f236766342d1ce96f978...    3679.0
# 4    cb5142698732aa569c90c8762ebdb0a7ed40330fa1abc6...    3348.0
# ..                                                 ...       ...
# 392  3e1d75f4aa1ecc2e7186f84b8526fc783dd9be494ae104...
# 393  3e1d75f4aa1ecc2e7186f84b8526fc783dd9be494ae104...
# 394  61e07ad3567f592c2b8d9f61dcdb23c6a942e9ebcb6761...
#
#                                              SUPER_CAT  \
# 0    5df3e4da2395aef5c8b3267b7253bb118eae178abf3d68...
# 1    5df3e4da2395aef5c8b3267b7253bb118eae178abf3d68...
# 2    5df3e4da2395aef5c8b3267b7253bb118eae178abf3d68...
# 3    5df3e4da2395aef5c8b3267b7253bb118eae178abf3d68...
# 4    5df3e4da2395aef5c8b3267b7253bb118eae178abf3d68...
# ..                                                 ...
# 390  d7a0999920f6139b0eb50b75a58a373b41b30098394b4d...
# 391  d7a0999920f6139b0eb50b75a58a373b41b30098394b4d...
# 392  d7a0999920f6139b0eb50b75a58a373b41b30098394b4d...
# 393  d7a0999920f6139b0eb50b75a58a373b41b30098394b4d...
# 394  1a51bb87d83a1e42f2a963ac1f8d6e8b6bd65c47136e6a...
#
#      ITEM_TOTAL_WEIGHT_OR_VOL_QTY
# 0                            16.0
# 1                           150.0
# 2                           512.0
# 3                           258.0
# 4                           160.0
# ..                            ...
# 390                         300.0
# 391                         102.0
# 392                         158.4
# 393                         150.0
# 394                         500.0
#
# [376 rows x 9 columns]

# %% [markdown]
# ### I will now iterate through catgories and for each item return the items of the category until aquiring four items by transaction ammount

# %%
item_with_four_recommendations_dict = {}

for item in items_with_super_cat_more_than_four_items["ITEM_NAME"].unique():
    recommended_items = []
    

    item_segment = items_with_super_cat_more_than_four_items[
        items_with_super_cat_more_than_four_items["ITEM_NAME"] == item
    ].sort_values('TRANSACTIONS', ascending=False)["SEGMENT"].values[0]
    
    segment_items = items_with_super_cat_more_than_four_items[
        items_with_super_cat_more_than_four_items["SEGMENT"] == item_segment
    ]
    for segment_item in segment_items["ITEM_NAME"]:
        if segment_item not in recommended_items:
            recommended_items.append(segment_item)
            if len(recommended_items) >= 5:
                break

    if len(recommended_items) < 5:
        sub_cat = items_with_super_cat_more_than_four_items[
            items_with_super_cat_more_than_four_items["ITEM_NAME"] == item
        ].sort_values('TRANSACTIONS', ascending=False)["SUB_CAT"].values[0]
        sub_cat_items = items_with_super_cat_more_than_four_items[
            items_with_super_cat_more_than_four_items["SUB_CAT"] == sub_cat
        ].sort_values('TRANSACTIONS', ascending=False)["ITEM_NAME"].values
        for sub_cat_item in sub_cat_items:
            if sub_cat_item not in recommended_items:
                recommended_items.append(sub_cat_item)
                if len(recommended_items) >= 5:
                    break

    if len(recommended_items) < 5:
        cat = items_with_super_cat_more_than_four_items[
            items_with_super_cat_more_than_four_items["ITEM_NAME"] == item
        ].sort_values('TRANSACTIONS', ascending=False)["CAT"].values[0]
        cat_items = items_with_super_cat_more_than_four_items[
            items_with_super_cat_more_than_four_items["CAT"] == cat
        ].sort_values('TRANSACTIONS', ascending=False)["ITEM_NAME"].values
        for cat_item in cat_items:
            if cat_item not in recommended_items:
                recommended_items.append(cat_item)
                if len(recommended_items) >= 5:
                    break

    if len(recommended_items) < 5:
        super_cat = items_with_super_cat_more_than_four_items[
            items_with_super_cat_more_than_four_items["ITEM_NAME"] == item
        ].sort_values('TRANSACTIONS', ascending=False)["SUPER_CAT"].values[0]
        super_cat_items = items_with_super_cat_more_than_four_items[
            items_with_super_cat_more_than_four_items["SUPER_CAT"] == super_cat
        ].sort_values('TRANSACTIONS', ascending=False)["ITEM_NAME"].values
        for super_cat_item in super_cat_items:
            if super_cat_item not in recommended_items:
                recommended_items.append(super_cat_item)
                if len(recommended_items) >= 5:
                    break

    item_for_dict = item
    list_for_dict = recommended_items[1:]
    
    item_with_four_recommendations_dict[item_for_dict] = list_for_dict

    print("Item: ", item_for_dict, "Recommended Items: ", item_with_four_recommendations_dict[item_for_dict], "Number of items: ", len(item_with_four_recommendations_dict[item_for_dict]))
# Out:
# Item:  Tena lady - extra plus duo pack x16 Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  Tena Lady Mini X20 Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  Tena lady - extra duo pack x20 Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  TENA LADY MAXI NIGHT x6 Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  Tena Lady Discreet Normal x16pc Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  TENA Lady Discreet Normal Pads x12 Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  TENA LADY EXTRA X10 Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  Always Discreet Sensitv Bladder Pad L+ 8 Recommended Items:  ['TENA Lady Discreet Normal Pads x12', 'Tena lady - extra plus duo pack x16', 'TENA LADY EXTRA X10', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  JS Comfort Pad Long Plus x8 Recommended Items:  ['TENA Lady Discreet Normal Pads x12', 'Tena lady - extra plus duo pack x16', 'TENA LADY EXTRA X10', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  TENA Lady Maxi Night x 12 Duo Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  lights by TENA Long Liner Duo x40 Recommended Items:  ['TENA Lady Discreet Normal Pads x12', 'Tena lady - extra plus duo pack x16', 'TENA LADY EXTRA X10', 'Tena Lady Discreet Normal x16pc'] Number of items:  4
# Item:  JS Chicken Liver 400g Recommended Items:  ['JS FRESH PIGS LIVER CW', 'JS Lambs Liver CW', 'SSTC Cooking Bacon 500g'] Number of items:  3
# Item:  JS FRESH PIGS LIVER CW Recommended Items:  ['JS FRESH PIGS LIVER CW', 'JS Lambs Liver CW', 'SSTC Cooking Bacon 500g'] Number of items:  3
# Item:  JS Lambs Liver CW Recommended Items:  ['JS FRESH PIGS LIVER CW', 'JS Lambs Liver CW', 'SSTC Cooking Bacon 500g'] Number of items:  3
# Item:  AHarriott Spice Sensation Couscous 100g Recommended Items:  ["Hubbard's Peach Slices 411g", 'Hubbards Spaghetti Rings 400g', "Hubbard's Strawberry Jam 454g", 'Hubbards Peanut Butter 340g'] Number of items:  4
# Item:  Caminada Malbec 75cl Recommended Items:  ['JS WS Mulled Wine 75cl', 'JS House Sauvignon Blanc 75cl', 'JS House Malbec 225cl', 'JS House Soave 75cl'] Number of items:  4
# Item:  Ovaltine Malted Original Drink 300g Recommended Items:  ['JS Corn Flakes 500g', "Daily's Oats 1kg", 'JS Rice Pops 375g', 'NESCAFE ORIGINAL COFFEE 300G'] Number of items:  4
# Item:  JS 6 Wholemeal Muffins Recommended Items:  ['Stamford Street Wholemeal Medium 800g', 'Stamford Street White Bread Medium 800g', 'JS Soft White Farmhouse 800g', 'Stamford St 8 Wholemeal Tortilla Wraps'] Number of items:  4
# Item:  Sainsburys Brandy 70cl Recommended Items:  ['Courvoisier VS Cognac 70cl', 'Triple Distilled British Vodka 1L', "Sainsbury's Vodka 70cl", 'Triple Distilled British Vodka 1.5L'] Number of items:  4
# Item:  Courvoisier VS Cognac 70cl Recommended Items:  ['Sainsburys Brandy 70cl', 'Triple Distilled British Vodka 1L', "Sainsbury's Vodka 70cl", 'Triple Distilled British Vodka 1.5L'] Number of items:  4
# Item:  Charlie Bigham's Thai Red Curry 835g Recommended Items:  ['JS Cheese & Onion Quiche 170g', 'Stamford St Cheese and Onion Quiche 400g', 'JS Pub Fish, Chips and Peas 450g', 'JS Chicken Casserole 400g'] Number of items:  4
# Item:  Trebor Softmints Spearmint Mints 4x44.9g Recommended Items:  ['Mentos Mint 5pk', 'Cadbury Delights Hazelnut 5pk 110g', 'JS CREAM CRACKER 300G', "McVitie's Club Orange Chocolate Biscuit"] Number of items:  4
# Item:  Mentos Mint 5pk Recommended Items:  ['Mentos Mint 5pk', 'Cadbury Delights Hazelnut 5pk 110g', 'JS CREAM CRACKER 300G', "McVitie's Club Orange Chocolate Biscuit"] Number of items:  4
# Item:  Stamford Street Mixed Vegetables 1kg Recommended Items:  ['Stamford Street Peas 850g', 'Stamford Street Sweetcorn 950g', 'Stamford St Large Pork Sausages 1kg', 'JS Rocket Lollies 8pkt 464ml'] Number of items:  4
# Item:  Stamford Street Peas 850g Recommended Items:  ['Stamford Street Mixed Vegetables 1kg', 'Stamford Street Sweetcorn 950g', 'Stamford St Large Pork Sausages 1kg', 'JS Rocket Lollies 8pkt 464ml'] Number of items:  4
# Item:  Stamford Street Sweetcorn 950g Recommended Items:  ['Stamford Street Peas 850g', 'Stamford Street Mixed Vegetables 1kg', 'Stamford St Large Pork Sausages 1kg', 'JS Rocket Lollies 8pkt 464ml'] Number of items:  4
# Item:  Diet Pepsi Caffeine Free 2L Recommended Items:  ['Pepsi Max cherry 1.25L', 'Coke 24x330ml', 'Pepsi Max Cherry 24x330ml', 'Hubbards Orange Double Con NAS 750ml'] Number of items:  4
# Item:  Coke 24x330ml Recommended Items:  ['Pepsi Max cherry 1.25L', 'Pepsi Max Cherry 24x330ml', 'Diet Pepsi Caffeine Free 2L', 'Hubbards Orange Double Con NAS 750ml'] Number of items:  4
# Item:  Pepsi Max Cherry 24x330ml Recommended Items:  ['Coke 24x330ml', 'Pepsi Max cherry 1.25L', 'Diet Pepsi Caffeine Free 2L', 'Hubbards Orange Double Con NAS 750ml'] Number of items:  4
# Item:  Pepsi Max cherry 1.25L Recommended Items:  ['Pepsi Max cherry 1.25L', 'Coke 24x330ml', 'Pepsi Max Cherry 24x330ml', 'Hubbards Orange Double Con NAS 750ml'] Number of items:  4
# Item:  JS BEANS IN TOMATO SAUCE 400G Recommended Items:  ['Hubbards Spaghetti Rings 400g', "Hubbard's Peach Slices 411g", "Hubbard's Strawberry Jam 454g", 'Hubbards Peanut Butter 340g'] Number of items:  4
# Item:  Hubbards Spaghetti Rings 400g Recommended Items:  ['JS BEANS IN TOMATO SAUCE 400G', "Hubbard's Peach Slices 411g", "Hubbard's Strawberry Jam 454g", 'Hubbards Peanut Butter 340g'] Number of items:  4
# Item:  Felix AGAIL senior meat selectn 12x100g Recommended Items:  ['Felix soup farm selection 6x48g', 'Purina One senior cat beef/chkn 8x85g', 'Felix soup fish selection 6x48g', 'Felix AGAIL d/delics ocean 12x100g'] Number of items:  4
# Item:  Felix soup farm selection 6x48g Recommended Items:  ['Felix soup farm selection 6x48g', 'Purina One senior cat beef/chkn 8x85g', 'Felix soup fish selection 6x48g', 'Felix AGAIL d/delics ocean 12x100g'] Number of items:  4
# Item:  Whiskas 2-12mths Kit Pouch fish 12x85g Recommended Items:  ['JS 1+ meat &fish selctn in jelly 48x100g', 'Whiskas 7+ Cat Pouch Poultry JEL 12x85g', 'JS 7+ meat&fish selctn in jelly 12x100g', 'Whiskas 1+ Cat Pouch Poultry jel 40x85g'] Number of items:  4
# Item:  Purina One senior cat beef/chkn 8x85g Recommended Items:  ['Felix soup farm selection 6x48g', 'Purina One senior cat beef/chkn 8x85g', 'Felix soup fish selection 6x48g', 'Felix AGAIL d/delics ocean 12x100g'] Number of items:  4
# Item:  Gourmet Perle chef's collection 12x85g Recommended Items:  ['Gourmet Perle ocean delicacies 12x85g', 'Gourmet mon petit cod/sard/salmon 6x50g', 'Gourmet Gold ocean fish paté 85g', 'Gourmet Perle country medley 12x85g'] Number of items:  4
# Item:  Gourmet Perle ocean delicacies 12x85g Recommended Items:  ['Gourmet Perle ocean delicacies 12x85g', 'Gourmet mon petit cod/sard/salmon 6x50g', 'Gourmet Gold ocean fish paté 85g', 'Gourmet Perle country medley 12x85g'] Number of items:  4
# Item:  Gourmet mon petit cod/sard/salmon 6x50g Recommended Items:  ['Gourmet Perle ocean delicacies 12x85g', 'Gourmet mon petit cod/sard/salmon 6x50g', 'Gourmet Gold ocean fish paté 85g', 'Gourmet Perle country medley 12x85g'] Number of items:  4
# Item:  JS 1+ meat &fish selctn in jelly 48x100g Recommended Items:  ['JS 1+ meat &fish selctn in jelly 48x100g', 'Whiskas 7+ Cat Pouch Poultry JEL 12x85g', 'JS 7+ meat&fish selctn in jelly 12x100g', 'Whiskas 1+ Cat Pouch Poultry jel 40x85g'] Number of items:  4
# Item:  
Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Wagg steaklets dog treats 125g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS dental sticks for large dogs x14 540g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Good Boy chewy chicken dumbbells 100g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS minty fresh dental sticks large 540g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS dental sticks for small dogs x14 220g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS log bones with chicken x2 200g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Dentalife ActivFresh dental small x7 Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS dog biscuits bone selection 650g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Misfits twistos with beef 105g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS meaty strips beef x20 200g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS twister with chicken & game x8 120g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Pedigree tasty minis puppy 125g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Wagg training treats 125g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS training treats rich in chicken 125g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Bonio original 1.2kg Recommended Items:  ['Winalot shapes 800g', 'JS biscuit selection for dogs 800g', 'JS meaty strips chicken x20 200g', 'JS meaty strips beef x20 200g'] Number of items:  4
# Item:  JS minty fresh dental sticks medium 360g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS gravy bones 400g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Bakers whirlers 130g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Good Boy chicken strips 100g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Wagg low fat treats 125g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS mini log bones with chicken x4 180g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Pedigree dentastix medium dog x28 720g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS deli sausages for dogs x8 60g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Winalot shapes 800g Recommended Items:  ['Winalot shapes 800g', 'JS biscuit selection for dogs 800g', 'JS meaty strips chicken x20 200g', 'JS meaty strips beef x20 200g'] Number of items:  4
# Item:  Good Boy chicken & calcium bones 100g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Pedigree dentastix small dog x7 110g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Pedigree tasty minis beef & cheese 140g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Stamford Street White Bread Medium 800g Recommended Items:  ['JS Soft White Farmhouse 800g', 'Stamford Street Wholemeal Medium 800g', 'JS 6 Wholemeal Muffins', 'Stamford St 8 Wholemeal Tortilla Wraps'] Number of items:  4
# Item:  JS Soft White Farmhouse 800g Recommended Items:  ['JS Soft White Farmhouse 800g', 'Stamford Street Wholemeal Medium 800g', 'JS 6 Wholemeal Muffins', 'Stamford St 8 Wholemeal Tortilla Wraps'] Number of items:  4
# Item:  Stamford Street Wholemeal Medium 800g Recommended Items:  ['JS Soft White Farmhouse 800g', 'Stamford Street Wholemeal Medium 800g', 'JS 6 Wholemeal Muffins', 'Stamford St 8 Wholemeal Tortilla Wraps'] Number of items:  4
# Item:  Cadbury Delights Hazelnut 5pk 110g Recommended Items:  ['Trebor Softmints Spearmint Mints 4x44.9g', 'Mentos Mint 5pk', 'JS CREAM CRACKER 300G', "McVitie's Club Orange Chocolate Biscuit"] Number of items:  4
# Item:  Felix AGAIL meat selct pork/duck 12x100g Recommended Items:  ['Felix soup farm selection 6x48g', 'Purina One senior cat beef/chkn 8x85g', 'Felix soup fish selection 6x48g', 'Felix AGAIL d/delics ocean 12x100g'] Number of items:  4
# Item:  Felix AGAIL kitten mixed selectn 12x100g Recommended Items:  ['Felix soup farm selection 6x48g', 'Purina One senior cat beef/chkn 8x85g', 'Felix soup fish selection 6x48g', 'Felix AGAIL d/delics ocean 12x100g'] Number of items:  4
# Item:  Whiskas 1+ Cat Pouch Poultry jel 12x85g Recommended Items:  ['JS 1+ meat &fish selctn in jelly 48x100g', 'Whiskas 7+ Cat Pouch Poultry JEL 12x85g', 'JS 7+ meat&fish selctn in jelly 12x100g', 'Whiskas 1+ Cat Pouch Poultry jel 40x85g'] Number of items:  4
# Item:  Felix mixed selection jelly 40x100g Recommended Items:  ['Felix soup farm selection 6x48g', 'Purina One senior cat beef/chkn 8x85g', 'Felix soup fish selection 6x48g', 'Felix AGAIL d/delics ocean 12x100g'] Number of items:  4
# Item:  Felix AGAIL d/delics senior 12x100g Recommended Items:  ['Felix soup farm selection 6x48g', 'Purina One senior cat beef/chkn 8x85g', 'Felix soup fish selection 6x48g', 'Felix AGAIL d/delics ocean 12x100g'] Number of items:  4
# Item:  Felix AGAIL favourites selection 12x100g Recommended Items:  ['Felix soup farm selection 6x48g', 'Purina One senior cat beef/chkn 8x85g', 'Felix soup fish selection 6x48g', 'Felix AGAIL d/delics ocean 12x100g'] Number of items:  4
# Item:  Gourmet Revelations mousse chicken 4x57g Recommended Items:  ['Gourmet Perle ocean delicacies 12x85g', 'Gourmet mon petit cod/sard/salmon 6x50g', 'Gourmet Gold ocean fish paté 85g', 'Gourmet Perle country medley 12x85g'] Number of items:  4
# Item:  Hubbards White Rice 1kg Recommended Items:  ["Hubbard's Peach Slices 411g", 'Hubbards Spaghetti Rings 400g', "Hubbard's Strawberry Jam 454g", 'Hubbards Peanut Butter 340g'] Number of items:  4
# Item:  Winders Strawberry Blackcurrant 5x17g Recommended Items:  ["Hubbard's Peach Slices 411g", 'Hubbards Spaghetti Rings 400g', "Hubbard's Strawberry Jam 454g", 'Hubbards Peanut Butter 340g'] Number of items:  4
# Item:  JS Raspberry Trifle 135g Recommended Items:  ['JS Lemon Cheesecakes 3x100g', 'GU CHOCOLATE GANACHE MOUSSE 2x70g', 'JS RASPBERRY TURNOVERS 2X65G', 'SSTC Natural Yoghurt 500g'] Number of items:  4
# Item:  JS Lemon Cheesecakes 3x100g Recommended Items:  ['JS Raspberry Trifle 135g', 'GU CHOCOLATE GANACHE MOUSSE 2x70g', 'JS RASPBERRY TURNOVERS 2X65G', 'SSTC Natural Yoghurt 500g'] Number of items:  4
# Item:  JS Smoked Salmon & Cream Cheese SW Recommended Items:  ['JS Bacon, Lettuce & Tomato BLT SW', 'JS Smoked Ham & Cheddar SW', 'JS 10 British chicken breast slices 115g', 'JS 4 boneless cooked chicken breast 480g'] Number of items:  4
# Item:  JS Bacon, Lettuce & Tomato BLT SW Recommended Items:  ['JS Bacon, Lettuce & Tomato BLT SW', 'JS Smoked Ham & Cheddar SW', 'JS 10 British chicken breast slices 115g', 'JS 4 boneless cooked chicken breast 480g'] Number of items:  4
# Item:  JS Smoked Ham & Cheddar SW Recommended Items:  ['JS Bacon, Lettuce & Tomato BLT SW', 'JS Smoked Salmon & Cream Cheese SW', 'JS 10 British chicken breast slices 115g', 'JS 4 boneless cooked chicken breast 480g'] Number of items:  4
# Item:  JS milky bones for small dogs 400g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Good Boy chewy lamb strips 80g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS biscuit selection for dogs 800g Recommended Items:  ['Winalot shapes 800g', 'JS biscuit selection for dogs 800g', 'JS meaty strips chicken x20 200g', 'JS meaty strips beef x20 200g'] Number of items:  4
# Item:  JS dental sticks medium dogs x14 360g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Good Boy chewy twists with chicken 90g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  Good Boy pigs in blankets 80g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS small biscuit bones for dogs 800g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS meaty strips chicken x20 200g Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g'] Number of items:  4
# Item:  JS Stuffed Crust Pepperoni Pizza 424g Recommended Items:  ['Stamford Street Peas 850g', 'Stamford Street Mixed Vegetables 1kg', 'Stamford Street Sweetcorn 950g', 'Stamford St Large Pork Sausages 1kg'] Number of items:  4
# Item:  Hubbard's Pasta Sauce 440g Recommended Items:  ['JS Flame Grilled Pizza Bases x2 300g', "Hubbard's Peach Slices 411g", 'Hubbards Spaghetti Rings 400g', "Hubbard's Strawberry Jam 454g"] Number of items:  4
# Item:  JS Flame Grilled Pizza Bases x2 300g Recommended Items:  ["Hubbard's Pasta Sauce 440g", "Hubbard's Peach Slices 411g", 'Hubbards Spaghetti Rings 400g', "Hubbard's Strawberry Jam 454g"] Number of items:  4
# Item:  SSTC SOFT CREAM CHEESE 200G Recommended Items:  ['SSTC GREEK STYLE SALAD CHEESE 200G', 'JS Butterlicious 500g', 'Anchor Spreadable 250G', 'JS Scottish Skimmed Milk 2 Pint 1.136L'] Number of items:  4
# Item:  JS Original Dry Cider 2lt Recommended Items:  ['Strongbow 18x440ml', 'JS Original Dry Cider 4x440ml', 'Thatchers Gold 10x440ml', 'Stella Artois 18x440ml'] Number of items:  4
# Item:  JS Original Dry Cider 4x440ml Recommended Items:  ['Strongbow 18x440ml', 'JS Original Dry Cider 2lt', 'Thatchers Gold 10x440ml', 'Stella Artois 18x440ml'] Number of items:  4
# Item:  Thatchers Gold 10x440ml Recommended Items:  ['Strongbow 18x440ml', 'JS Original Dry Cider 4x440ml', 'JS Original Dry Cider 2lt', 'Stella Artois 18x440ml'] Number of items:  4
# Item:  Strongbow 18x440ml Recommended Items:  ['JS Original Dry Cider 4x440ml', 'JS Original Dry Cider 2lt', 'Thatchers Gold 10x440ml', 'Stella Artois 18x440ml'] Number of items:  4
# Item:  Walkers Meaty 20pk Recommended Items:  ['Walkers Variety 20pk', 'Walkers Cheese&Onion 12pk', 'WALKERS QUAVERS CHEESE 12x16g', 'DORITOS TANGY CHEESE 5pk'] Number of items:  4
# Item:  Walkers Variety 20pk Recommended Items:  ['Walkers Variety 20pk', 'Walkers Cheese&Onion 12pk', 'WALKERS QUAVERS CHEESE 12x16g', 'DORITOS TANGY CHEESE 5pk'] Number of items:  4
# Item:  Walkers Cheese&Onion 12pk Recommended Items:  ['Walkers Variety 20pk', 'Walkers Cheese&Onion 12pk', 'WALKERS QUAVERS CHEESE 12x16g', 'DORITOS TANGY CHEESE 5pk'] Number of items:  4
# Item:  Oatly Oat Drink Skinny 1l Recommended Items:  ['JS Butterlicious 500g', 'Anchor Spreadable 250G', 'Stamford St. Soft Spread 500g', 'SSTC SOFT CREAM CHEESE 200G'] Number of items:  4
# Item:  SSTC Cooking Bacon 500g Recommended Items:  ['JS Lambs Liver CW', 'JS Chicken Liver 400g', 'JS FRESH PIGS LIVER CW'] Number of items:  3
# Item:  JS Medium Dry Amontillado Sherry 1L Recommended Items:  ['Triple Distilled British Vodka 1L', "Sainsbury's Vodka 70cl", 'Triple Distilled British Vodka 1.5L', 'Sainsburys Brandy 70cl'] Number of items:  4
# Item:  Arctic Coffee Latte 330ml Recommended Items:  ['SSTC SOFT CREAM CHEESE 200G', 'JS Butterlicious 500g', 'SSTC GREEK STYLE SALAD CHEESE 200G', 'Anchor Spreadable 250G'] Number of items:  4
# Item:  Daily's Oats 1kg Recommended Items:  ['JS Corn Flakes 500g', 'JS Rice Pops 375g', 'JS Balance Red Fruit 375g', 'Klg Spec K Red Berries 330g'] Number of items:  4
# Item:  JS RASPBERRY TURNOVERS 2X65G Recommended Items:  ['JS Lemon Cheesecakes 3x100g', 'JS Raspberry Trifle 135g', 'GU CHOCOLATE GANACHE MOUSSE 2x70g', 'SSTC Natural Yoghurt 500g'] Number of items:  4
# Item:  JS Steak & Kidney Puff Pastry Pie 150g Recommended Items:  ["Charlie Bigham's Thai Red Curry 835g", 'JS Cheese & Onion Quiche 170g', 'Stamford St Cheese and Onion Quiche 400g', 'JS Pub Fish, Chips and Peas 450g'] Number of items:  4
# Item:  Bernard Matthews Turkey Chunks 80g Recommended Items:  ['JS 4 boneless cooked chicken breast 480g', 'JS 10 British chicken breast slices 115g', 'JS 10 British beef slices 115g', 'PREMIER DELI OX TONGUE 125g'] Number of items:  4
# Item:  JS 4 boneless cooked chicken breast 480g Recommended Items:  ['Bernard Matthews Turkey Chunks 80g', 'JS 10 British chicken breast slices 115g', 'JS 10 British beef slices 115g', 'PREMIER DELI OX TONGUE 125g'] Number of items:  4
# Item:  Pot Noodle King Pot Beef & Tomato 114g Recommended Items:  ["Hubbard's Peach Slices 411g", 'Hubbards Spaghetti Rings 400g', "Hubbard's Strawberry Jam 454g", 'Hubbards Peanut Butter 340
 'Whiskas 7+ complete chicken 1.9kg', 'Go-Cat adult tuna herring & veg 750g'] Number of items:  4
# Item:  Go-Cat senior 2kg Recommended Items:  ['Go Cat senior chicken rice & veg 750g', 'Whiskas 7+ complete chicken 1.9kg', 'Go-Cat adult tuna herring & veg 750g', 'Go-Cat adult chicken & duck 2kg'] Number of items:  4
# Item:  Whiskas 1+ dry cat food chicken 800g Recommended Items:  ['Go Cat senior chicken rice & veg 750g', 'Whiskas 7+ complete chicken 1.9kg', 'Go-Cat adult tuna herring & veg 750g', 'Go-Cat adult chicken & duck 2kg'] Number of items:  4
# Item:  JS Rice Pops 375g Recommended Items:  ['JS Corn Flakes 500g', 'Nestle Cheerios Honey 370g', "Daily's Oats 1kg", 'JS Balance Red Fruit 375g'] Number of items:  4
# Item:  JS Corn Flakes 500g Recommended Items:  ['JS Rice Pops 375g', 'Nestle Cheerios Honey 370g', "Daily's Oats 1kg", 'JS Balance Red Fruit 375g'] Number of items:  4
# Item:  Nestle Cheerios Honey 370g Recommended Items:  ['JS Corn Flakes 500g', 'JS Rice Pops 375g', "Daily's Oats 1kg", 'JS Balance Red Fruit 375g'] Number of items:  4
# Item:  JS Stamford Street Chips 1.5 kg Recommended Items:  ['Stamford Street Peas 850g', 'Stamford Street Mixed Vegetables 1kg', 'Stamford Street Sweetcorn 950g', 'Stamford St Large Pork Sausages 1kg'] Number of items:  4
# Item:  Twinings Everyday 80 Tea Bags 232g Recommended Items:  ['JS Corn Flakes 500g', "Daily's Oats 1kg", 'JS Rice Pops 375g', 'NESCAFE ORIGINAL COFFEE 300G'] Number of items:  4
# Item:  Activia Fibre Walnut & Oat Breakfast Gu Recommended Items:  ['SSTC Natural Yoghurt 500g', 'Actimel Blueberry 8x100g', 'ACTIVIA FUSIONS PRUNE YOGURT 4x120g', 'BENECOL BLUEBERRY 6X67.5G'] Number of items:  4
# Item:  Tango Paradise Punch 8x330ml Recommended Items:  ['Old Jamaica ginger beer 1.5L', 'Hubbards Orange Double Con NAS 750ml', 'Coke 24x330ml', 'JS DIET INDIAN TONIC WATER 1L'] Number of items:  4
# Item:  Old Jamaica ginger beer 1.5L Recommended Items:  ['Tango Paradise Punch 8x330ml', 'Hubbards Orange Double Con NAS 750ml', 'Coke 24x330ml', 'JS DIET INDIAN TONIC WATER 1L'] Number of items:  4
# Item:  POLIGRIP FLV FREE DENT FIXATIVE CRM 40G Recommended Items:  ['FIXODENT ADHESIVE CREAM ORIGINAL 40G', 'Fixodent Dual Power 40g', 'TENA Lady Discreet Normal Pads x12', 'Tena lady - extra plus duo pack x16'] Number of items:  4
# Item:  FIXODENT ADHESIVE CREAM ORIGINAL 40G Recommended Items:  ['FIXODENT ADHESIVE CREAM ORIGINAL 40G', 'Fixodent Dual Power 40g', 'TENA Lady Discreet Normal Pads x12', 'Tena lady - extra plus duo pack x16'] Number of items:  4
# Item:  Fixodent Dual Power 40g Recommended Items:  ['FIXODENT ADHESIVE CREAM ORIGINAL 40G', 'Fixodent Dual Power 40g', 'TENA Lady Discreet Normal Pads x12', 'Tena lady - extra plus duo pack x16'] Number of items:  4
# Item:  Nescafe Dolce Gusto Americano 128g Recommended Items:  ['Nestle Dolce Gusto Flat White 187.20g', 'Nescafe DG Americano Intenso x16 132.8g', 'Nescafe Dolce Gusto Cappuccino x8 186g', 'Nescafe DG Latte Macchiato Pods x16'] Number of items:  4
# Item:  Nestle Dolce Gusto Flat White 187.20g Recommended Items:  ['Nestle Dolce Gusto Flat White 187.20g', 'Nescafe DG Americano Intenso x16 132.8g', 'Nescafe Dolce Gusto Cappuccino x8 186g', 'Nescafe DG Latte Macchiato Pods x16'] Number of items:  4
# Item:  Nescafe DG Americano Intenso x16 132.8g Recommended Items:  ['Nestle Dolce Gusto Flat White 187.20g', 'Nescafe DG Americano Intenso x16 132.8g', 'Nescafe Dolce Gusto Cappuccino x8 186g', 'Nescafe DG Latte Macchiato Pods x16'] Number of items:  4
# ...
# Item:  Dreamies cat treats chicken 60g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Webbox turkey & lamb tasty sticks x6 30g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Webbox cat sticks with duck x6 30g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS snack pockets cheese 65g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Felix goody bag original/party mix 200g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS deli sticks salmon & trout x10 50g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Webbox salmon & trout tasty stick x6 30g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Dreamies cat treats chicken & duck 60g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Webbox lick-e-lix chicken 5x15g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Dreamies cat treats tuna salmon mix 60g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Felix goody bag seaside/ocean mix 60g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS snack pockets with chicken 65g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS snack pockets with trky/beef/duck 65g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS snack pockets catnip 65g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Felix goody bag seaside mix 200g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Felix goody bag mixed grill 60g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Whiskas dentabites chicken 50g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS snack pockets with salmon 65g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS cat milk 3x200ml Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Webbox lick-e-lix salmon 5x15g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Dreamies cat treats cheese 60g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Dreamies cat treats beef 60g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  Dreamies cat treats salmon 60g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS deli sticks chicken & liver x10 50g Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g'] Number of items:  4
# Item:  JS wildbird suet balls x10 Recommended Items:  ['JS wildbird seed mix 4kg', 'JS wildbird seed mix 750g', 'JS wildbird peanuts 750g', 'Catsan hygiene cat litter 10L'] Number of items:  4
# Item:  JS wildbird seed mix 4kg Recommended Items:  ['JS wildbird seed mix 4kg', 'JS wildbird seed mix 750g', 'JS wildbird peanuts 750g', 'Catsan hygiene cat litter 10L'] Number of items:  4
# Item:  JS wildbird seed mix 750g Recommended Items:  ['JS wildbird seed mix 4kg', 'JS wildbird seed mix 750g', 'JS wildbird peanuts 750g', 'Catsan hygiene cat litter 10L'] Number of items:  4
# Item:  JS wildbird peanuts 750g Recommended Items:  ['JS wildbird seed mix 4kg', 'JS wildbird seed mix 750g', 'JS wildbird peanuts 750g', 'Catsan hygiene cat litter 10L'] Number of items:  4
# Item:  JS comn for seniors meat in jelly 6x400g Recommended Items:  ['JS comn meat selectn in jelly 12x400g', 'JS comn meaty loaf selection 6x400g', 'Pedigree meaty meals in jelly 6x385g', "Butcher's simply gentle cans 6x390g"] Number of items:  4
# Item:  Cesar classic terrine mix 8x150g Recommended Items:  ['Winalot perfect portions pouches 40x100g', "Lily's Kitchen chkn trky casserole 150g", 'Cesar country stew selection 8x150g', 'JS comn meat selectn in gravy 12x400g'] Number of items:  4
# Item:  JS comn meat selectn in jelly 12x400g Recommended Items:  ['JS comn meat selectn in jelly 12x400g', 'JS comn meaty loaf selection 6x400g', 'Pedigree meaty meals in jelly 6x385g', "Butcher's simply gentle cans 6x390g"] Number of items:  4
# Item:  JS comn meaty loaf selection 6x400g Recommended Items:  ['JS comn meat selectn in jelly 12x400g', 'JS comn meaty loaf selection 6x400g', 'Pedigree meaty meals in jelly 6x385g', "Butcher's simply gentle cans 6x390g"] Number of items:  4
# Item:  Winalot perfect portions pouches 40x100g Recommended Items:  ['Winalot perfect portions pouches 40x100g', "Lily's Kitchen chkn trky casserole 150g", 'Cesar country stew selection 8x150g', 'JS comn meat selectn in gravy 12x400g'] Number of items:  4
# Item:  Pedigree meaty meals in jelly 6x385g Recommended Items:  ['JS comn meat selectn in jelly 12x400g', 'JS comn meaty loaf selection 6x400g', 'Pedigree meaty meals in jelly 6x385g', "Butcher's simply gentle cans 6x390g"] Number of items:  4
# Item:  Butcher's simply gentle cans 6x390g Recommended Items:  ['JS comn meat selectn in jelly 12x400g', 'JS comn meaty loaf selection 6x400g', 'Pedigree meaty meals in jelly 6x385g', "Butcher's simply gentle cans 6x390g"] Number of items:  4
# Item:  JS comn meat selectn in gravy 12x400g Recommended Items:  ['JS comn meat selectn in jelly 12x400g', 'JS comn meaty loaf selection 6x400g', 'Pedigree meaty meals in jelly 6x385g', "Butcher's simply gentle cans 6x390g"] Number of items:  4
# Item:  Lily's Kitchen chkn trky casserole 150g Recommended Items:  ['Winalot perfect portions pouches 40x100g', "Lily's Kitchen chkn trky casserole 150g", 'Cesar country stew selection 8x150g', 'JS comn meat selectn in gravy 12x400g'] Number of items:  4
# Item:  Butcher's tripe loaf recipes 12x400g Recommended Items:  ['JS comn meat selectn in jelly 12x400g', 'JS comn meaty loaf selection 6x400g', 'Pedigree meaty meals in jelly 6x385g', "Butcher's simply gentle cans 6x390g"] Number of items:  4
# Item:  Cesar country stew selection 8x150g Recommended Items:  ['Winalot perfect portions pouches 40x100g', "Lily's Kitchen chkn trky casserole 150g", 'Cesar country stew selection 8x150g', 'JS comn meat selectn in gravy 12x400g'] Number of items:  4
# Item:  JS DIET INDIAN TONIC WATER 1L Recommended Items:  ['Hubbards Orange Double Con NAS 750ml', 'Coke 24x330ml', 'Old Jamaica ginger beer 1.5L', 'JS Strawberry&Kiwi Still Water 4x500ml'] Number of items:  4
# Item:  Gaviscon Double Action tablets x48 Recommended Items:  ['Panadol Advance tablets x16', 'Panadol Extra Advance x14', 'Panadol Extra soluble x24', 'TENA Lady Discreet Normal Pads x12'] Number of items:  4
# Item:  Kronenbourg 1664 15x440ml Recommended Items:  ['Budweiser 18x440ml', 'Stella Artois 18x440ml', 'Carling Lager 18x440ml', 'Fosters 18x440ml'] Number of items:  4
# Item:  Carling Lager 18x440ml Recommended Items:  ['Fosters 18x440ml', 'Fosters 12x440ml', 'Stella Artois 18x440ml', 'Kronenbourg 1664 15x440ml'] Number of items:  4
# Item:  Fosters 18x440ml Recommended Items:  ['Fosters 18x440ml', 'Fosters 12x440ml', 'Stella Artois 18x440ml', 'Kronenbourg 1664 15x440ml'] Number of items:  4
# Item:  Heineken 15x440ml Recommended Items:  ['Stella Artois 18x440ml', 'Carling Lager 18x440ml', 'Fosters 18x440ml', 'Kronenbourg 1664 15x440ml'] Number of items:  4
# Item:  Fosters 12x440ml Recommended Items:  ['Fosters 18x440ml', 'Fosters 12x440ml', 'Stella Artois 18x440ml', 'Kronenbourg 1664 15x440ml'] Number of items:  4
# Item:  Budweiser 18x440ml Recommended Items:  ['Budweiser 18x440ml', 'Stella Artois 18x440ml', 'Carling Lager 18x440ml', 'Fosters 18x440ml'] Number of items:  4
# Item:  Stella Artois 18x440ml Recommended Items:  ['Budweiser 18x440ml', 'Stella Artois 18x440ml', 'Carling Lager 18x440ml', 'Fosters 18x440ml'] Number of items:  4
# Item:  JS adult comn with chicken & veg 2.5kg Recommended Items:  ['JS adult comn with chicken & veg 5kg', 'JS senior comn with chicken & rice 2.5kg', 'JS meaty strips chicken x20 200g', 'JS meaty strips beef x20 200g'] Number of items:  4
# Item:  JS adult comn with chicken & veg 5kg Recommended Items:  ['JS adult comn with chicken & veg 5kg', 'JS senior comn with chicken & rice 2.5kg', 'JS meaty strips chicken x20 200g', 'JS meaty strips beef x20 200g'] Number of items:  4
# Item:  JS senior comn with chicken & rice 2.5kg Recommended Items:  ['JS adult comn with chicken & veg 5kg', 'JS senior comn with chicken & rice 2.5kg', 'JS meaty strips chicken x20 200g', 'JS meaty strips beef x20 200g'] Number of items:  4
# Item:  PREMIER DELI OX TONGUE 125g Recommended Items:  ['JS 10 British chicken breast slices 115g', 'JS 10 British beef slices 115g', 'JS 4 boneless cooked chicken breast 480g', 'Bernard Matthews Turkey Chunks 80g'] Number of items:  4
# Item:  JS 10 British chicken breast slices 115g Recommended Items:  ['JS 10 British beef slices 115g', 'PREMIER DELI OX TONGUE 125g', 'JS 4 boneless cooked chicken breast 480g', 'Bernard Matthews Turkey Chunks 80g'] Number of items:  4
# Item:  JS 10 British beef slices 115g Recommended Items:  ['JS 10 British beef slices 115g', 'PREMIER DELI OX TONGUE 125g', 'JS 4 boneless cooked chicken breast 480g', 'Bernard Matthews Turkey Chunks 80g'] Number of items:  4
# Item:  JS Balance Red Fruit 375g Recommended Items:  ['Klg Spec K Red Berries 330g', 'Klg Spec K Peach & Apricot 360g', "Kellogg's Special K Red Berries 500g", "Kellogg's Wheats Apricot 500g"] Number of items:  4
# Item:  Kellogg's Just Right 500g Recommended Items:  ["Kellogg's Fruit n Fibre 375g", 'JS Balance Red Fruit 375g', 'Klg Spec K Red Berries 330g', "Kellogg's Special K Red Berries 500g"] Number of items:  4
# Item:  Klg Spec K Red Berries 330g Recommended Items:  ['Klg Spec K Red Berries 330g', 'Klg Spec K Peach & Apricot 360g', "Kellogg's Special K Red Berries 500g", "Kellogg's Wheats Apricot 500g"] Number of items:  4
# Item:  Kellogg's Fruit n Fibre 375g Recommended Items:  ["Kellogg's Fruit n Fibre 375g", 'JS Balance Red Fruit 375g', 'Klg Spec K Red Berries 330g', "Kellogg's Special K Red Berries 500g"] Number of items:  4
# Item:  Klg Spec K Peach & Apricot 360g Recommended Items:  ['Klg Spec K Red Berries 330g', 'Klg Spec K Peach & Apricot 360g', "Kellogg's Special K Red Berries 500g", "Kellogg's Wheats Apricot 500g"] Number of items:  4
# Item:  Kellogg's Wheats Apricot 500g Recommended Items:  ['JS Balance Red Fruit 375g', 'Klg Spec K Red Berries 330g', "Kellogg's Special K Red Berries 500g", "Kellogg's Fruit n Fibre 375g"] Number of items:  4
# Item:  Kellogg's Special K Red Berries 500g Recommended Items:  ['Klg Spec K Red Berries 330g', 'Klg Spec K Peach & Apricot 360g', "Kellogg's Special K Red Berries 500g", "Kellogg's Wheats Apricot 500g"] Number of items:  4
# Item:  Js Broccoli Chse/tomato Ind quiche 170g Recommended Items:  ['JS Cheese & Onion Quiche 170g', 'Stamford St Cheese and Onion Quiche 400g', "Charlie Bigham's Thai Red Curry 835g", 'JS Pub Fish, Chips and Peas 450g'] Number of items:  4
# Item:  JS Cheese & Onion Quiche 170g Recommended Items:  ['JS Cheese & Onion Quiche 170g', 'Stamford St Cheese and Onion Quiche 400g', "Charlie Bigham's Thai Red Curry 835g", 'JS Pub Fish, Chips and Peas 450g'] Number of items:  4
# Item:  Stamford St Cheese and Onion Quiche 400g Recommended Items:  ['JS Cheese & Onion Quiche 170g', 'Js Broccoli Chse/tomato Ind quiche 170g', "Charlie Bigham's Thai Red Curry 835g", 'JS Pub Fish, Chips and Peas 450g'] Number of items:  4
# Item:  Landlord Pale Ale 500ml nrb Recommended Items:  ['Stella Artois 18x440ml', 'Carling Lager 18x440ml', 'Fosters 18x440ml', 'Kronenbourg 1664 15x440ml'] Number of items:  4
# Item:  NESCAFE ORIGINAL COFFEE 300G Recommended Items:  ["L'OR Intense Coffee 150g", 'Nescafe Cafe Irish Cream Latte 158g', 'Nescafe Original 3in1 102g', 'Nestle Dolce Gusto Flat White 187.20g'] Number of items:  4
# Item:  Nescafe Original 3in1 102g Recommended Items:  ['NESCAFE ORIGINAL COFFEE 300G', "L'OR Intense Coffee 150g", 'Nescafe Cafe Irish Cream Latte 158g', 'Nestle Dolce Gusto Flat White 187.20g'] Number of items:  4
# Item:  Nescafe Cafe Irish Cream Latte 158g Recommended Items:  ['NESCAFE ORIGINAL COFFEE 300G', "L'OR Intense Coffee 150g", 'Nescafe Original 3in1 102g', 'Nestle Dolce Gusto Flat White 187.20g'] Number of items:  4
# Item:  L'OR Intense Coffee 150g Recommended Items:  ['NESCAFE ORIGINAL COFFEE 300G', 'Nescafe Cafe Irish Cream Latte 158g', 'Nescafe Original 3in1 102g', 'Nestle Dolce Gusto Flat White 187.20g'] Number of items:  4
# Item:  SSTC Natural Yoghurt 500g Recommended Items:  ['Activia Fibre Walnut & Oat Breakfast Gu', 'Actimel Blueberry 8x100g', 'ACTIVIA FUSIONS PRUNE YOGURT 4x120g', 'BENECOL BLUEBERRY 6X67.5G'] Number of items:  4

# %% [markdown]
# so now we can take our items with not enough super cat and use cosine similarity to find an item that is similar and copy its recommendations

# %%
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] 
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-mpnet-base-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-mpnet-base-v2')

# %%
def get_embeddings(sentences):
  encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

  with torch.no_grad():
      model_output = model(**encoded_input)

  sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

  sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)

  return sentence_embeddings

# %%
def remove_company_names(df, column, company_names, new_column=None):
    copy_df = df.copy()
    cleaned_column = copy_df[column].copy()
    for name in company_names:
        cleaned_column = cleaned_column.str.replace(name, '', regex=False).str.strip()
    
    if new_column:
        copy_df[new_column] = cleaned_column
    else:
        copy_df[column] = cleaned_column
    
    return copy_df


company_names = ['Stamford Street', 'JS ', 'SSTC', 'Stamford St', 'Sainsburys']

# %%
items_in_super_cats_with_less_than_four_items = remove_company_names(
    items_in_super_cats_with_less_than_four_items, 'ITEM_NAME', company_names, 'ITEM_NAME_CLEANED'
)
items_with_super_cat_more_than_four_items = remove_company_names(
    items_with_super_cat_more_than_four_items, 'ITEM_NAME', company_names, 'ITEM_NAME_CLEANED'
)

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

embed_df = items_with_super_cat_more_than_four_items.copy()

product_embeddings = model.encode(items_with_super_cat_more_than_four_items['ITEM_NAME_CLEANED'].tolist())

# %%
def get_recommendations(query, embeddings, df, top_n=200):
    copy_df = df.copy()
    query_embedding = model.encode([query])
    similarities = cosine_similarity(query_embedding, embeddings)
    top_indices = similarities[0].argsort()[-top_n:][::-1]
    copy_df['COSINE_SIMILARITY'] = similarities[0]
    return copy_df.iloc[top_indices]

# %%
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

for item_for_swap in items_in_super_cats_with_less_than_four_items['ITEM_NAME_CLEANED'].values:
    query = item_for_swap
    recommendations = get_recommendations(query, product_embeddings, embed_df, top_n=1)
    top_cosine_item = recommendations['ITEM_NAME'].values[0]

    copied_recomendations = item_with_four_recommendations_dict[top_cosine_item]

    item_for_dict = items_in_super_cats_with_less_than_four_items[items_in_super_cats_with_less_than_four_items['ITEM_NAME_CLEANED'] == item_for_swap]['ITEM_NAME'].values[0]
    list_for_dict = copied_recomendations
    
    item_with_four_recommendations_dict[item_for_dict] = list_for_dict

    print("\nItem for swap: ", item_for_dict, 
          "\nTaking Recommendations From: ", top_cosine_item, 
          "\nRecommended Items: ", list_for_dict)
# Out:
# Item for swap:  Dairy Pride UHT Skimmed Milk 1l
# Taking Recommendations From:  JS Scottish Skimmed Milk 2 Pint 1.136L
# Recommended Items:  ['SSTC SOFT CREAM CHEESE 200G', 'JS Butterlicious 500g', 'SSTC GREEK STYLE SALAD CHEESE 200G', 'Anchor Spreadable 250G']
#
# Item for swap:  Dairy Pride Semi Skimmed UHT Milk 1ltr
# Taking Recommendations From:  JS Scottish Skimmed Milk 2 Pint 1.136L
# Recommended Items:  ['SSTC SOFT CREAM CHEESE 200G', 'JS Butterlicious 500g', 'SSTC GREEK STYLE SALAD CHEESE 200G', 'Anchor Spreadable 250G']
#
# Item for swap:  Rizla Regular Green x 5 Multi Pack
# Taking Recommendations From:  Tena lady - extra plus duo pack x16
# Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc']
#
# Item for swap:  Swan Extra Slim Filter Tips X120
# Taking Recommendations From:  Strongbow 18x440ml
# Recommended Items:  ['JS Original Dry Cider 4x440ml', 'JS Original Dry Cider 2lt', 'Thatchers Gold 10x440ml', 'Stella Artois 18x440ml']
#
# Item for swap:  LITTLE ONES DRY FIT  6+EP 30
# Taking Recommendations From:  Tena lady - extra plus duo pack x16
# Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc']
#
# Item for swap:  TV TIMES 22/23
# Taking Recommendations From:  TENA Lady Maxi Night x 12 Duo
# Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc']
#
# Item for swap:  Stamford Street Strawberry &Vanilla Roll
# Taking Recommendations From:  Hubbard's Strawberry Jam 454g
# Recommended Items:  ['JS Reduced Sugar Strawberry Jam 415g', 'Hubbards Peanut Butter 340g', 'JS Reduced Salt Yeast Extract 225g', "Hubbard'Orange Medium Cut Marmalade 454g"]
#
# Item for swap:  Stamford Street Fairy Cakes X12
# Taking Recommendations From:  JS Lemon Cheesecakes 3x100g
# Recommended Items:  ['JS Raspberry Trifle 135g', 'GU CHOCOLATE GANACHE MOUSSE 2x70g', 'JS RASPBERRY TURNOVERS 2X65G', 'SSTC Natural Yoghurt 500g']
#
# Item for swap:  Stamford Street Mini Rolls 102g
# Taking Recommendations From:  JS meaty rolls x15 135g
# Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g']
#
# Item for swap:  TAKE A BREAK
# Taking Recommendations From:  Cadbury Timeout 6 pack
# Recommended Items:  ["McVitie's Club Orange Chocolate Biscuit", 'WAGON WHEELS JAMMIE 229g', 'Kit Kat dark choc 2 finger 9pk', "McVitie's Club  Mint x7"]
#
# Item for swap:  JS Lamb Breast CW
# Taking Recommendations From:  JS Lambs Liver CW
# Recommended Items:  ['JS FRESH PIGS LIVER CW', 'JS Lambs Liver CW', 'SSTC Cooking Bacon 500g']
#
# Item for swap:  Dettol antiseptic disinfectant 750ml
# Taking Recommendations From:  Sainsbury's Apple Shampoo 500ml
# Recommended Items:  ['TENA Lady Discreet Normal Pads x12', 'Tena lady - extra plus duo pack x16', 'Panadol Advance tablets x16', 'TENA LADY EXTRA X10']
#
# Item for swap:  JS BRITISH LARGE PORK SHOULDER JOINT CW
# Taking Recommendations From:  Stamford St Large Pork Sausages 1kg
# Recommended Items:  ['Stamford St Beef Burgers x8 397g', 'JS Roast Lamb Dinner 400g', 'JS chicken hotpot dinner 400g', "Young's Salmon Fillet Dinner 380g"]
#
# Item for swap:  JS ADW Ultimate Lem 262g 20 washes
# Taking Recommendations From:  Bakers whirlers 130g
# Recommended Items:  ['Good Boy chicken bites 65g', 'JS doggy donuts with chicken 200g', 'JS biscuit rolls with beef 550g', 'JS mini log bones with chicken 200g']
#
# Item for swap:  Stamford St White Fish Fillets 520g
# Taking Recommendations From:  Young's Salmon Fillet Dinner 380g
# Recommended Items:  ['JS Roast Lamb Dinner 400g', 'JS chicken hotpot dinner 400g', 'Stamford St Large Pork Sausages 1kg', 'Stamford St Beef Burgers x8 397g']
#
# Item for swap:  Comfort creations strawberry lily 30w
# Taking Recommendations From:  Winders Strawberry Blackcurrant 5x17g
# Recommended Items:  ["Hubbard's Peach Slices 411g", 'Hubbards Spaghetti Rings 400g', "Hubbard's Strawberry Jam 454g", 'Hubbards Peanut Butter 340g']
#
# Item for swap:  Stamford St Mixed Portions Pack 2kg
# Taking Recommendations From:  Stamford Street Mixed Vegetables 1kg
# Recommended Items:  ['Stamford Street Peas 850g', 'Stamford Street Sweetcorn 950g', 'Stamford St Large Pork Sausages 1kg', 'JS Rocket Lollies 8pkt 464ml']
#
# Item for swap:  Js Frozen Chicken Liver Pots 250g
# Taking Recommendations From:  JS deli sticks chicken & liver x10 50g
# Recommended Items:  ['Whiskas temptations chicken & cheese 60g', 'Webbox chckn & liver tasty sticks x6 30g', 'Dreamies cat treats chicken 60g', 'Webbox turkey & lamb tasty sticks x6 30g']
#
# Item for swap:  Regina Blitz x4
# Taking Recommendations From:  TENA LADY MAXI NIGHT x6
# Recommended Items:  ['Tena Lady Mini X20', 'Tena lady - extra duo pack x20', 'TENA LADY MAXI NIGHT x6', 'Tena Lady Discreet Normal x16pc']

# %%
recommendations_df = pd.DataFrame.from_dict(item_with_four_recommendations_dict, orient='index')

recommendations_df.columns = [f"RECOMMENDATION {i+1}" for i in range(recommendations_df.shape[1])]

recommendations_df = recommendations_df.reset_index().rename(columns={'index': 'ITEM_NAME'})

recommendations_df
# Out:
#                                  ITEM_NAME  \
# 0      Tena lady - extra plus duo pack x16
# 1                       Tena Lady Mini X20
# 2           Tena lady - extra duo pack x20
# 3                  TENA LADY MAXI NIGHT x6
# 4          Tena Lady Discreet Normal x16pc
# ..                                     ...
# 390    Stamford St White Fish Fillets 520g
# 391  Comfort creations strawberry lily 30w
# 392    Stamford St Mixed Portions Pack 2kg
# 393      Js Frozen Chicken Liver Pots 250g
# 394                        Regina Blitz x4
#
#                              RECOMMENDATION 1  \
# 0                          Tena Lady Mini X20
# 1                          Tena Lady Mini X20
# 2                          Tena Lady Mini X20
# 3                          Tena Lady Mini X20
# 4                          Tena Lady Mini X20
# ..                                        ...
# 390                 JS Roast Lamb Dinner 400g
# 391               Hubbard's Peach Slices 411g
# 392                 Stamford Street Peas 850g
# 393  Whiskas temptations chicken & cheese 60g
# 394                        Tena Lady Mini X20
#
#                              RECOMMENDATION 2  \
# 0              Tena lady - extra duo pack x20
# 1              Tena lady - extra duo pack x20
# 2              Tena lady - extra duo pack x20
# 3              Tena lady - extra duo pack x20
# 4              Tena lady - extra duo pack x20
# ..                                        ...
# 390             JS chicken hotpot dinner 400g
# 391             Hubbards Spaghetti Rings 400g
# 392            Stamford Street Sweetcorn 950g
# 393  Webbox chckn & liver tasty sticks x6 30g
# 394            Tena lady - extra duo pack x20
#
#                         RECOMMENDATION 3  \
# 0                TENA LADY MAXI NIGHT x6
# 1                TENA LADY MAXI NIGHT x6
# 2                TENA LADY MAXI NIGHT x6
# 3                TENA LADY MAXI NIGHT x6
# 4                TENA LADY MAXI NIGHT x6
# ..                                   ...
# 390  Stamford St Large Pork Sausages 1kg
# 391        Hubbard's Strawberry Jam 454g
# 392  Stamford St Large Pork Sausages 1kg
# 393      Dreamies cat treats chicken 60g
# 394              TENA LADY MAXI NIGHT x6
#
#                              RECOMMENDATION 4
# 0             Tena Lady Discreet Normal x16pc
# 1             Tena Lady Discreet Normal x16pc
# 2             Tena Lady Discreet Normal x16pc
# 3             Tena Lady Discreet Normal x16pc
# 4             Tena Lady Discreet Normal x16pc
# ..                                        ...
# 390          Stamford St Beef Burgers x8 397g
# 391               Hubbards Peanut Butter 340g
# 392              JS Rocket Lollies 8pkt 464ml
# 393  Webbox turkey & lamb tasty sticks x6 30g
# 394           Tena Lady Discreet Normal x16pc
#
# [395 rows x 5 columns]
